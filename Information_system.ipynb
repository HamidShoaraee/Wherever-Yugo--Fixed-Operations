# %%
from PIL import Image

# %% [markdown]
# The new information system is based on the integration of both service and part departments. In this Notebook, we want to have a feasibility study on how we can propose the new information system for the Yugo car dealership.
# The workflow between customer, service advisor, service technician, and the part advisor will be as follow:

# %%
workFlow = Image.open('workFlow.png')
workFlow
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1713x1094 at 0x25F76DEBD88>

# %% [markdown]
# The Data flow diagram is a great diagram for illustrating the flow of information, sources of data, and how that data is stored. In the following you can find the data flow of the new solution.

# %%
dataFlow =  Image.open('dataFlow.png')
dataFlow
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1922x1329 at 0x25F76EB9C48>

# %% [markdown]
# The data flow within the new system makes the data to be available for all the departments. All the departments can connect to the system to send and receive the data that they need. For more clarification between departments and the flow of the data the context diagram can help us.

# %%
CD =  Image.open('CD.png')
CD
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1536x940 at 0x25F76EC2408>

# %% [markdown]
# Another diagram that can help us is Use case diagram. The use case diagram shows the interaction between users and the system.
# The main components of the Use case diagram are as follow:
# * System
# * Actors
# * Use cases
# * Relationships

# %%
useDiagram = Image.open('UseDiagram.png')
useDiagram
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1513x1012 at 0x25F76EC2CC8>

# %% [markdown]
# For the implementation of this study and run this project we determine tasks that we need to follow. Also for each task, We consider the estimated duration for each task based on similar projects and the average of group estimation. The Work Breakdown Structure shows in the next plot. This project can start on the 1st of June and will finish on the 22nd of December.

# %%
wbs = Image.open('WBS.png')
wbs
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1641x1375 at 0x25F76EC5508>
